# %% [markdown]
# # Phoenix DB Client Example

# %% [markdown]
# ### You can load a dataset into a Phoenix table via the PhoenixDB library

# %% [markdown]
# #### First, create a database connection. Notice Phoenix credentials are saved into your CML Project as environment variables.
# #### To add yours, navigate to Project Settings -> Advanced -> Add the variables for your user and restart the CML session.

# %% [markdown]
# Helper Functions

# %%
import pandas as pd

# %%
class Db:
    def __init__(self):
        opts = {}
        opts['authentication'] = 'BASIC'
        opts['avatica_user'] = os.environ["WORKLOAD_USER"]
        opts['avatica_password'] = os.environ["WORKLOAD_PASSWORD"]
        database_url = os.environ["OPDB_ENDPOINT_PSE"]
        self.TABLENAME = "test_table_paul"
        self.conn = phoenixdb.connect(database_url, autocommit=True,**opts)
        self.curs = self.conn.cursor()
        
    def create_linkage_table(self):
        
        query = """
        CREATE TABLE IF NOT EXISTS "CML_WORKSHOP_TABLE" (
        unique_id VARCHAR,
        first_name VARCHAR,
        surname VARCHAR,
        dob VARCHAR,
        city  VARCHAR,
        email VARCHAR,
        groupp VARCHAR CONSTRAINT my_pk PRIMARY KEY (unique_id))
        """
        
        self.curs.execute(query)
        
    def upsert_linkage(self, data):

        sql = """upsert into "CML_WORKSHOP_TABLE" \
             (unique_id ,first_name,surname,dob,city,email,groupp) \
             values (?,?,?,?,?,?,?)"""
        #print(data)
        self.curs.executemany(sql,data)
        self.conn.commit()
        
    def get_data(self):

        query = f"SELECT count(*) FROM CML_WORKSHOP_TABLE"

        model.curs.execute(query)
        rows = model.curs.fetchall()

        return rows

# %%
def upsert_data(data, records=100):
        total_records=0
        header = True
        rows = []
        i=1
        model=Db()
        for index, row in data.iterrows():

            rows.append ([f"{row['unique_id']}",\
                      f"{row['first_name']}",f"{row['surname']}",\
                      f"{row['dob']}",f"{row['city']}", \
                      f"{row['email']}", f"{row['group']}"])
            total_records=total_records+1

            if i < records + 1 :   
                i=i+1
            else :
                model.upsert_linkage(rows)
                rows = []
                i=1
                print (f"Ingested {total_records} records")

        if len(rows) > 0 :
            model.upsert_linkage(rows)

        print (f"Ingested {total_records} records")

# %% [markdown]
# #### In order to demonstrate this, we will load the sample dataset into a Phoenix table.

# %%
df= pd.read_parquet("data/fake_df_l.parquet", engine="pyarrow")

# %%
df.head()
# Out:
#    unique_id first_name  surname         dob          city  \
# 0          0     Julia      None  2015-10-29        London
# 1          4       oNah   Watson  2008-03-23        Bolton
# 2         13     Molly      Bell  2002-01-05  Peterborough
# 3         15  Alexander  Amelia   1983-05-19       Glasgow
# 4         20     Ol vri  ynnollC  1972-03-08      Plymouth
#
#                             email  group
# 0             hannah88@powers.com      0
# 1  matthew78@ballard-mcdonald.net      1
# 2                            None      2
# 3        ic-mpbell@allealewis.org      3
# 4        derekwilliams@norris.com      4

# %%
import logging
logging.basicConfig( level=logging.DEBUG)

import os
import phoenixdb
model=Db()
# Out:
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "372bef52-f42b-44c6-b536-c2b6015150e1"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n?org.apache.calcite.avatica.proto.Requests$OpenConnectionRequest\x12&\n$372bef52-f42b-44c6-b536-c2b6015150e1' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 134
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$OpenConnectionResponse"
# wrapped_message: "\n?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "372bef52-f42b-44c6-b536-c2b6015150e1"
# conn_props {
#   auto_commit: true
#   has_auto_commit: true
#   has_read_only: true
# }
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n?org.apache.calcite.avatica.proto.Requests$ConnectionSyncRequest\x12.\n$372bef52-f42b-44c6-b536-c2b6015150e1\x12\x06\x10\x018\x01@\x01' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 144
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$ConnectionSyncResponse"
# wrapped_message: "\n\010\020\001 \0028\001@\001\022?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "b68dcc2e-216b-4f02-ac9e-3c5836efaa6a"
# statement_id: 12
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n?org.apache.calcite.avatica.proto.Requests$CloseStatementRequest\x12(\n$b68dcc2e-216b-4f02-ac9e-3c5836efaa6a\x10\x0c' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 134
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$CloseStatementResponse"
# wrapped_message: "\n?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "b68dcc2e-216b-4f02-ac9e-3c5836efaa6a"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n@org.apache.calcite.avatica.proto.Requests$CloseConnectionRequest\x12&\n$b68dcc2e-216b-4f02-ac9e-3c5836efaa6a' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 135
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$CloseConnectionResponse"
# wrapped_message: "\n?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"

# %%
import logging
logging.basicConfig( level=logging.DEBUG)

#model.drop_stocks_table()
model.create_linkage_table()
# Out:
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "b68dcc2e-216b-4f02-ac9e-3c5836efaa6a"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n@org.apache.calcite.avatica.proto.Requests$CreateStatementRequest\x12&\n$b68dcc2e-216b-4f02-ac9e-3c5836efaa6a' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 175
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$CreateStatementResponse"
# wrapped_message: "\n$b68dcc2e-216b-4f02-ac9e-3c5836efaa6a\020\014\032?\n=cod-ojgyjyaq708e-worker1.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "b68dcc2e-216b-4f02-ac9e-3c5836efaa6a"
# sql: "\n        CREATE TABLE IF NOT EXISTS \"CML_WORKSHOP_TABLE\" (\n        unique_id VARCHAR,\n        first_name VARCHAR,\n        surname VARCHAR,\n        dob VARCHAR,\n        city  VARCHAR,\n        email VARCHAR,\n        groupp VARCHAR CONSTRAINT my_pk PRIMARY KEY (unique_id))\n        "
# statement_id: 12
# first_frame_max_size: 2000
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\nBorg.apache.calcite.avatica.proto.Requests$PrepareAndExecuteRequest\x12\xc5\x02\n$b68dcc2e-216b-4f02-ac9e-3c5836efaa6a\x12\x97\x02\n        CREATE TABLE IF NOT EXISTS "CML_WORKSHOP_TABLE" (\n        unique_id VARCHAR,\n        first_name VARCHAR,\n        surname VARCHAR,\n        dob VARCHAR,\n        city  VARCHAR,\n        email VARCHAR,\n        groupp VARCHAR CONSTRAINT my_pk PRIMARY KEY (unique_id))\n         \x0c0\xd0\x0f' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 129
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$ExecuteResponse"
# wrapped_message: "\020\001\032?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"

# %% [markdown]
# #### Next, navigate to the COD Experience in CDP and open the Hue browser.
# #### Check that the table is there.

# %%
import logging
logging.basicConfig( level=logging.DEBUG)

upsert_data(df)
# Out:
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "cdf377b2-b908-49b1-8b12-85a9b13f5272"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n?org.apache.calcite.avatica.proto.Requests$OpenConnectionRequest\x12&\n$cdf377b2-b908-49b1-8b12-85a9b13f5272' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 134
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$OpenConnectionResponse"
# wrapped_message: "\n?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "cdf377b2-b908-49b1-8b12-85a9b13f5272"
# conn_props {
#   auto_commit: true
#   has_auto_commit: true
#   has_read_only: true
# }
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n?org.apache.calcite.avatica.proto.Requests$ConnectionSyncRequest\x12.\n$cdf377b2-b908-49b1-8b12-85a9b13f5272\x12\x06\x10\x018\x01@\x01' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 144
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$ConnectionSyncResponse"
# wrapped_message: "\n\010\020\001 \0028\001@\001\022?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "cdf377b2-b908-49b1-8b12-85a9b13f5272"
# sql: "upsert into \"CML_WORKSHOP_TABLE\"              (unique_id ,first_name,surname,dob,city,email,groupp)              values (?,?,?,?,?,?,?)"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n8org.apache.calcite.avatica.proto.Requests$PrepareRequest\x12\xb0\x01\n$cdf377b2-b908-49b1-8b12-85a9b13f5272\x12\x87\x01upsert into "CML_WORKSHOP_TABLE"              (unique_id ,first_name,surname,dob,city,email,groupp)              values (?,?,?,?,?,?,?)' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 559
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$PrepareResponse"
# wrapped_message: "\n\254\003\n$cdf377b2-b908-49b1-8b12-85a9b13f5272\032\203\003\022\207\001upsert into \"CML_WORKSHOP_TABLE\"              (unique_id ,first_name,surname,dob,city,email,groupp)              values (?,?,?,?,?,?,?)\032! \014*\007VARCHAR2\020java.lang.String:\002?1\032! \014*\007VARCHAR2\020java.lang.String:\002?2\032! \014*\007VARCHAR2\020java.lang.String:\002?3\032! \014*\007VARCHAR2\020java.lang.String:\002?4\032! \014*\007VARCHAR2\020java.lang.String:\002?5\032! \014*\007VARCHAR2\020java.lang.String:\002?6\032! \014*\007VARCHAR2\020java.lang.String:\002?7\"\002\010\004\022?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "cdf377b2-b908-49b1-8b12-85a9b13f5272"
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "0"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Julia "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2015-10-29"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "hannah88@powers.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "0"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "4"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "oNah"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Watson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2008-03-23"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Bolton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "matthew78@ballard-mcdonald.net"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "13"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Molly "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Bell"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2002-01-05"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Peterborough"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "15"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Alexander"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Amelia "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1983-05-19"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Glasgow"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "ic-mpbell@allealewis.org"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "3"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "20"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ol vri"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "ynnollC"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1972-03-08"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Plymouth"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "derekwilliams@norris.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "4"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "23"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Thompson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1996-03-22"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Leeds"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "jefferyduke@brown-salazar.org"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "5"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "27"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Matilda "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Hsrir"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1983-04-30"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "patrcio47@davis.cam"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "6"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "32"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Baxter"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Aria "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1992-09-07"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "christineshepherd@allen.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "7"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "37"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Wilson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Charlie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1998-09-15"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "samantha81@henry.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "8"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "38"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Olivia "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Andrews"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2009-01-23"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "hesterkurt@taylor-fitzgerald.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "9"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "43"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Chloe "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Macdonald"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2015-02-04"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "jennifer25@hill.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "10"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "44"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Millie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Harrs"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1996-07-27"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "lynn04@jones.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "11"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "49"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Theodore "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1982-09-10"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Leeds"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "markstewart@gross.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "12"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "58"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Elijah "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1970-06-01"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sunderland"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "barbaraolson@smith.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "13"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "63"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Maya "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jones"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2010-08-05"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sunderland"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "erin01@york.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "14"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "69"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Isabella "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Coepo"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1987-11-18"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Stockton-Tn-oee"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "imoore@turner-gonzalez.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "15"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "79"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Carr"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ethan "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2013-01-21"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "stacyball@medina.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "16"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "88"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Eva "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Harris"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1971-01-29"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Birmingham"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "vwilson@reyes-torres.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "17"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "89"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Chirla "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Taylor"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2006-06-28"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "mbrooks@booker.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "18"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "91"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lilly "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jones"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2003-12-30"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "samue91rcu@ry.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "19"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "96"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Morris"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Noah "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1983-07-20"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Birmingham"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "20"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "105"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Harry "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Tomas"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2011-07-30"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Belast"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "sandra26@anderson-davis.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "21"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "115"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ells"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2013-01-20"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Stoke-on-Trent"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "wmcdaniel@nelson.net"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "22"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "122"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Isabella "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Wallca"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2000-03-24"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "hilltheresa@pearson.org"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "23"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "128"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Edward "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "wLis"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2005-04-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "whitakernichole@booth.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "24"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "133"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Harriet "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jones"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1980-06-23"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "trobinson@garza.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "25"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "142"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Harry "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Taylor"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2017-11-24"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "coltonray@lee.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "26"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "149"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "aHry "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Hill"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2017-12-05"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sheffield"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "zporter@robinson.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "27"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "156"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Enht "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Brow"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2010-12-22"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Manchester"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "petersbrandon@cox.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "28"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "164"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Nathan "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Mcdonald"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1996-09-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "barbara84@robbins.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "29"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "172"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Clara "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Bolton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2013-06-11"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "judy30@smith.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "30"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "176"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1983-11-16"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Leeds"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "31"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "185"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Gray"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jessica "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1971-08-18"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "scottcervantes@johnson-rich.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "32"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "188"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Eva "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "leB"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2001-08-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "shepcerdtara@fores.hom"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "33"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "194"
#   }
#   parameter_values {
#     type: STRING
#     string_value: " acob"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1987-02-06"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Southend-on-Sea"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "barrygary@flores.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "34"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "204"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "J cob"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Thomas"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2007-05-28"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sudlreand"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "hknapp@davis-allen.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "35"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "209"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Thompson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Freddie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1999-07-23"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Peterborough"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "scottsalinas@hughes-lopez.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "36"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "213"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Fisher"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2002-10-07"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Derby"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "ke@in40vharrell.ne"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "37"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "219"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Esme "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Davies"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2011-07-19"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Bristol"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "gordonlaurie@harvey.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "38"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "220"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Amber "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Smith"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2003-05-12"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "barrerakevin@sherman.org"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "39"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "229"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Charlotte "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1995-06-15"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sunderland"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "toddsean@wilkins-burton.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "40"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "237"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Turner"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1990-03-21"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "onorman@walker.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "41"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "243"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "iredFe "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Bartlett"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1979-02-19"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "virginia80@henson.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "42"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "244"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Joshua "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Harrison"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2015-09-06"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sounhetd-onSea"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "zacharymays@hill.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "43"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "252"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Mohammed "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Owen"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2018-01-14"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Cardiff"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "44"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "261"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Florence "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Morris"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1993-01-29"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Southampton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "paul49@allen.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "45"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "266"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Robertson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Charlie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2016-09-26"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "gomezjohn@brooks.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "46"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "275"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lil "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "kacJon"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2000-07-30"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Mansfied"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "lewischristopher@alack-thombs.et"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "47"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "279"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jackson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sara "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1999-11-04"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Liverpool"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "kimashley@nguyen.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "48"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "289"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Arol"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Morgan"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2015-05-15"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Aberdeen"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "charles81@nelson.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "49"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "296"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jasper "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1981-07-25"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "martinsusan@woods.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "50"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "301"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Isabelle "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "orBw"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1979-01-22"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Stoke-on-Trent"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "joshphwatson@smite.co"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "51"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "311"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Harrison "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "obsGn"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2005-04-24"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lnodn"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "elizabeth81@smith.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "52"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "315"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lee"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2000-07-29"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "zlynch@miller.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "53"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "316"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Emily "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Brooks"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1974-03-21"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "millssamuel@alvarez-henry.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "54"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "326"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Smith"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1991-02-26"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Southampton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "lisaharmon@montgomery.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "55"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "331"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Daniel "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Griffiths"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2013-06-21"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "karen05@morrow.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "56"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "332"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Gabriel "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1977-12-21"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Leds"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "rachelschtitm@geore-walker.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "57"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "338"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Spencer"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lucas "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2007-10-26"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Swansea"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "58"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "341"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "rFddie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lane"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2016-02-18"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "duanejames@reyes.net"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "59"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "348"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Freya "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "sgheH"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2018-04-28"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "nodoL"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "60"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "352"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Wallace"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "George "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2018-10-31"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "StkeTon--rent"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "jonathan74@glover.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "61"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "362"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Taylor"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1989-07-25"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "wagnershane@landry.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "62"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "368"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lewis"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Freddie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1971-12-19"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Southend-on-Sea"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "tyler28@weaver-alvarez.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "63"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "372"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Adam "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Berry"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1986-02-08"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "walterdunn@pham-hill.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "64"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "382"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lewis"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2017-02-05"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Raeing"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "james08@hernandez.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "65"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "388"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Roberts"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2003-12-16"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "ryannoble@bryant.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "66"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "394"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Davis"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2001-07-13"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ipswich"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "jose33@trujillo.net"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "67"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "404"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Archie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "George"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1976-04-07"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "warrenanna@stuart-brooks.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "68"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "408"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Phillips"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Alex "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1991-04-05"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Glasog"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "xsmith@cooper-garcia.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "69"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "413"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Mia "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Cooke"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2013-12-31"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "courtneywilson@smith.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "70"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "419"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Emily "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Brown"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2005-07-15"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lndon"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "sarahbrown@mckinney.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "71"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "428"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Oliver "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Thompson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2012-02-04"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "amandn06@suttoa.cm"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "72"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "431"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lucy "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Stone"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2011-11-26"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Middbeslough"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "ppruitt@kirby.org"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "73"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "437"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Johnson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1993-01-31"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Middlesrough"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "maureenwagnr@baroett.cnm"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "74"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "438"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Mohammad "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Williams"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1997-07-18"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Swansea"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "sholland@burke.net"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "75"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "440"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Richards"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Charlie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1991-03-13"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Northampton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "jacobstafford@hamilton.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "76"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "449"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ivy "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Cunningham"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1990-11-20"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Nwrich"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "77"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "453"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Alfie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Catre"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1997-02-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "jcnnifermarshall@browning.eo"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "78"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "463"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Isaac "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Taylor"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2008-09-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Swndon"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "xday@higgins-lewis.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "79"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "467"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Gegre "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Kennedy"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1984-07-05"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "jonesjustin@myers.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "80"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "469"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Hn yr"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2012-11-30"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Newcastle-upon-Tyne"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "laura12@nelson.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "81"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "476"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Campbell"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Mia "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2005-02-12"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "stevenanderson@pierce.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "82"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "479"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jack "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Adams"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1976-08-27"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Leicester"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "becky18@roberts-frazier.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "83"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "488"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Cross"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Thomas "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1992-10-16"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "orusso@hanmck.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "84"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "494"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Arlo "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Porter"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1982-01-27"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "debla30@ner.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "85"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "495"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "nrGt"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1991-06-27"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ipswich"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "margaret50@garrett.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "86"
#   }
# }
# updates {
# ...
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1971-10-26"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Leeds"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "dawn74@mckay.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "164"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "918"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Evie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Collns"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1988-10-25"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lonod"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "travis53@enmen.cos"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "165"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "922"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Anderson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2003-10-03"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Lndon"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "166"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "924"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Mills"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Thomas "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1970-03-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "hensondebbie@garcia.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "167"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "933"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "George "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Hodgson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1980-12-30"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sheffield"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "lori88@huynh.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "168"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "941"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Oscar "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1985-03-26"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "York"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "carlos74@byrd.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "169"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "947"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "mAeli "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Johnson"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1985-05-04"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Luton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "zlsondanielle@martino.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "170"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "955"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Teddy "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Walker"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1996-11-28"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Leicester"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "michelle49@turner.org"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "171"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "958"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Smith"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Gracie "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2016-05-13"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "172"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "960"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Gabriel "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Bartlett"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1973-12-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Wolverhampton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "ogomez@robinson-mckinney.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "173"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "967"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Isla "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2008-05-07"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Bolton"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "susanmoreno@edwards-wallace.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "174"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "971"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Taylor"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1978-05-09"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ldnon"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "tiffanyrodriguez@rodriguez-yu.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "175"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "976"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Layla "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "all"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1991-12-29"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Newcastle-upon-Tyne"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "stacykelly@brown.info"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "176"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "986"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ellis "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Jones"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1997-11-18"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "tammy46@bailey-lee.net"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "177"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "987"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sophia "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Ellis"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1981-08-14"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Sheffield"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "danielle24@garcia-jones.net"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "178"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "991"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "liL "
#   }
#   parameter_values {
#     type: STRING
#     string_value: "Young"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "1995-09-05"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "wesleykidd@miller.com"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "179"
#   }
# }
# updates {
#   parameter_values {
#     type: STRING
#     string_value: "998"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "None"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "King"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "2015-09-21"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "London"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "christopherpierce@hoffman-ross.biz"
#   }
#   parameter_values {
#     type: STRING
#     string_value: "180"
#   }
# }
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n=org.apache.calcite.avatica.proto.Requests$ExecuteBatchRequest\x12\x93?\n$cdf377b2-b908-49b1-8b12-85a9b13f5272\x10\x01\x1a_\n\x07\x08\x15\x1a\x03603\n\x08\x08\x15\x1a\x04None\n\x06\x08\x15\x1a\x02Ky\n\x0e\x08\x15\x1a\n1996-05-13\n\x0f\x08\x15\x1a\x0boeteborPugh\n\x18\x08\x15\x1a\x14seancollins@dean.com\n\x07\x08\x15\x1a\x03101\x1a^\n\x07\x08\x15\x1a\x03612\n\n\x08\x15\x1a\x06Caleb \n\x07\x08\x15\x1a\x03Kan\n\x0e\x08\x15\x1a\n2000-10-09\n\r\x08\x15\x1a\tWirangton\n\x16\x08\x15\x1a\x12vmoreno@ussell.zib\n\x07\x08\x15\x1a\x03102\x1aj\n\x07\x08\x15\x1a\x03614\n\n\x08\x15\x1a\x06Wright\n\t\x08\x15\x1a\x05Jude \n\x0e\x08\x15\x1a\n2017-03-28\n\x0b\x08\x15\x1a\x07Belfast\n"\x08\x15\x1a\x1elynnchapman@crawfard-lozon.com\n\x07\x08\x15\x1a\x03103\x1a_\n\x07\x08\x15\x1a\x03615\n\x0c\x08\x15\x1a\x08Jessica \n\x08\x08\x15\x1a\x04Carr\n\x0e\x08\x15\x1a\n1972-02-07\n\x08\x08\x15\x1a\x04None\n\x19\x08\x15\x1a\x15wramirez@robinson.com\n\x07\x08\x15\x1a\x03104\x1ad\n\x07\x08\x15\x1a\x03618\n\x0b\x08\x15\x1a\x07Arthur \n\n\x08\x15\x1a\x06Bolton\n\x0e\x08\x15\x1a\n1998-03-07\n\x0e\x08\x15\x1a\nNottingham\n\x17\x08\x15\x1a\x13milesnine@floras.iz\n\x07\x08\x15\x1a\x03105\x1a`\n\x07\x08\x15\x1a\x03626\n\n\x08\x15\x1a\x06Alfie \n\x08\x08\x15\x1a\x04None\n\x0e\x08\x15\x1a\n2015-02-05\n\n\x08\x15\x1a\x06London\n\x1a\x08\x15\x1a\x16garci.richard@bradycom\n\x07\x08\x15\x1a\x03106\x1a]\n\x07\x08\x15\x1a\x03632\n\t\x08\x15\x1a\x05Noah \n\n\x08\x15\x1a\x06Gibson\n\x0e\x08\x15\x1a\n1987-05-18\n\n\x08\x15\x1a\x06London\n\x16\x08\x15\x1a\x12avazquez@banks.com\n\x07\x08\x15\x1a\x03107\x1aQ\n\x07\x08\x15\x1a\x03642\n\n\x08\x15\x1a\x06Gordon\n\x0b\x08\x15\x1a\x07Olivia \n\x0e\x08\x15\x1a\n1993-01-19\n\n\x08\x15\x1a\x06London\n\x08\x08\x15\x1a\x04None\n\x07\x08\x15\x1a\x03108\x1aP\n\x07\x08\x15\x1a\x03644\n\x0b\x08\x15\x1a\x07Daniel \n\n\x08\x15\x1a\x06Palmer\n\x0e\x08\x15\x1a\n2016-06-14\n\t\x08\x15\x1a\x05oodLn\n\x08\x08\x15\x1a\x04None\n\x07\x08\x15\x1a\x03109\x1ao\n\x07\x08\x15\x1a\x03650\n\n\x08\x15\x1a\x06Logan \n\x0c\x08\x15\x1a\x08Thompson\n\x0e\x08\x15\x1a\n2009-03-25\n\x17\x08\x15\x1a\x13Newcastle-upon-Tyne\n\x18\x08\x15\x1a\x14mike46@contreras.biz\n\x07\x08\x15\x1a\x03110\x1aN\n\x07\x08\x15\x1a\x03651\n\t\x08\x15\x1a\x05Walsh\n\t\x08\x15\x1a\x05Ella \n\x0e\x08\x15\x1a\n1978-12-04\n\n\x08\x15\x1a\x06Milton\n\x08\x08\x15\x1a\x04None\n\x07\x08\x15\x1a\x03111\x1af\n\x07\x08\x15\x1a\x03654\n\x08\x08\x15\x1a\x04None\n\x0b\x08\x15\x1a\x07Cameron\n\x0e\x08\x15\x1a\n2018-06-18\n\x0f\x08\x15\x1a\x0bBournemouth\n\x1a\x08\x15\x1a\x16fisherdaniel@smith.com\n\x07\x08\x15\x1a\x03112\x1a_\n\x07\x08\x15\x1a\x03664\n\x08\x08\x15\x1a\x04Ivy \n\n\x08\x15\x1a\x06Taylor\n\x0e\x08\x15\x1a\n1980-01-13\n\t\x08\x15\x1a\x05Lonon\n\x1a\x08\x15\x1a\x16jonesjennmfer@pitt.coi\n\x07\x08\x15\x1a\x03113\x1ak\n\x07\x08\x15\x1a\x03674\n\n\x08\x15\x1a\x06Saeni \n\n\x08\x15\x1a\x06Davies\n\x0e\x08\x15\x1a\n2016-01-10\n\x0c\x08\x15\x1a\x08Plymouth\n!\x08\x15\x1a\x1dheather69@martin-bradford.biz\n\x07\x08\x15\x1a\x03114\x1a[\n\x07\x08\x15\x1a\x03682\n\x08\x08\x15\x1a\x04None\n\n\x08\x15\x1a\x06Taylor\n\x0e\x08\x15\x1a\n2014-03-20\n\n\x08\x15\x1a\x06London\n\x15\x08\x15\x1a\x11eaul44@bpntly.com\n\x07\x08\x15\x1a\x03115\x1aq\n\x07\x08\x15\x1a\x03684\n\t\x08\x15\x1a\x05Emma \n\t\x08\x15\x1a\x05Dixon\n\x0e\x08\x15\x1a\n2013-11-25\n\x14\x08\x15\x1a\x10Stockton-on-Tees\n!\x08\x15\x1a\x1dmaynardhaley@clark-graves.com\n\x07\x08\x15\x1a\x03116\x1ab\n\x07\x08\x15\x1a\x03686\n\n\x08\x15\x1a\x06Logan \n\x0c\x08\x15\x1a\x08Nichosno\n\x0e\x08\x15\x1a\n1999-04-14\n\x0b\x08\x15\x1a\x07Glasgow\n\x17\x08\x15\x1a\x13longdebra@dixon.com\n\x07\x08\x15\x1a\x03117\x1aa\n\x07\x08\x15\x1a\x03694\n\n\x08\x15\x1a\x06 nleyF\n\t\x08\x15\x1a\x05Grant\n\x0e\x08\x15\x1a\n2003-07-12\n\x0b\x08\x15\x1a\x07Salford\n\x19\x08\x15\x1a\x15brownsierra@price.com\n\x07\x08\x15\x1a\x03118\x1a`\ ...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 255
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$ExecuteBatchResponse"
# wrapped_message: "\n$cdf377b2-b908-49b1-8b12-85a9b13f5272\020\001\032P\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001\001*?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "cdf377b2-b908-49b1-8b12-85a9b13f5272"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n7org.apache.calcite.avatica.proto.Requests$CommitRequest\x12&\n$cdf377b2-b908-49b1-8b12-85a9b13f5272' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 59
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$CommitResponse"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "cdf377b2-b908-49b1-8b12-85a9b13f5272"
# statement_id: 1
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n?org.apache.calcite.avatica.proto.Requests$CloseStatementRequest\x12(\n$cdf377b2-b908-49b1-8b12-85a9b13f5272\x10\x01' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 134
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$CloseStatementResponse"
# wrapped_message: "\n?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "cdf377b2-b908-49b1-8b12-85a9b13f5272"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n@org.apache.calcite.avatica.proto.Requests$CloseConnectionRequest\x12&\n$cdf377b2-b908-49b1-8b12-85a9b13f5272' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# Ingested 181 records
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 135
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$CloseConnectionResponse"
# wrapped_message: "\n?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"

# %% [markdown]
# #### Finally, check that the upsert worked:

# %%
model.get_data()
# Out:
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "372bef52-f42b-44c6-b536-c2b6015150e1"
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b'\n@org.apache.calcite.avatica.proto.Requests$CreateStatementRequest\x12&\n$372bef52-f42b-44c6-b536-c2b6015150e1' {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 175
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$CreateStatementResponse"
# wrapped_message: "\n$372bef52-f42b-44c6-b536-c2b6015150e1\020\002\032?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
#
# DEBUG:phoenixdb.avatica.client:Sending request
# connection_id: "372bef52-f42b-44c6-b536-c2b6015150e1"
# sql: "SELECT count(*) FROM CML_WORKSHOP_TABLE"
# statement_id: 2
# first_frame_max_size: 2000
#
# DEBUG:phoenixdb.avatica.client:POST https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site/cod-ojgyjyaq708e/cdp-proxy-api/avatica b"\nBorg.apache.calcite.avatica.proto.Requests$PrepareAndExecuteRequest\x12T\n$372bef52-f42b-44c6-b536-c2b6015150e1\x12'SELECT count(*) FROM CML_WORKSHOP_TABLE \x020\xd0\x0f" {'content-type': 'application/x-google-protobuf'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443
# DEBUG:urllib3.connectionpool:https://cod-ojgyjyaq708e-gateway0.pse-722.ylcu-atmi.cloudera.site:443 "POST /cod-ojgyjyaq708e/cdp-proxy-api/avatica HTTP/1.1" 200 366
# DEBUG:phoenixdb.avatica.client:Received response
# name: "org.apache.calcite.avatica.proto.Responses$ExecuteResponse"
# wrapped_message: "\n\353\001\n$372bef52-f42b-44c6-b536-c2b6015150e1\020\002\030\001\"]\nW\030\001 \0018\001@(J\010COUNT(1)R\010COUNT(1)r\022CML_WORKSHOP_TABLE\200\001\001\232\001\016java.lang.Long\242\001\020\010\373\377\377\377\017\022\006BIGINT\030\005\"\002\010\004*\024\020\001\032\020\n\016\n\005\010\r \352\002\"\005\010\r \352\0020\377\377\377\377\377\377\377\377\377\001:?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765\032?\n=cod-ojgyjyaq708e-worker4.pse-722.ylcu-atmi.cloudera.site:8765"
# [[181]]
